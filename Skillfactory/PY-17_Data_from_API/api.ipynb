# %%
# Токен
# 1e3c445f1e3c445f1e3c445f7b1d2b10c811e3c1e3c445f7be8fe4d9961f0eccdb46c54

# %%
# Перейдите по следующей ниже ссылке в браузере, подставив вместо слова TOKEN ваш персональный сервисный ключ доступа (токен), полученный на предыдущем шаге:

# https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token=1e3c445f1e3c445f1e3c445f7b1d2b10c811e3c1e3c445f7be8fe4d9961f0eccdb46c54

# %%
# ЗАПРОС К API ИЗ КОДА
# Продолжаем пользоваться всё той же библиотекой requests.

import requests # Импортируем модуль requests
token = '1e3c445f1e3c445f1e3c445f7b1d2b10c811e3c1e3c445f7be8fe4d9961f0eccdb46c54' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %%
# Словари нагляднее выводить с помощью функции pprint(), которую мы уже использовали ранее:

from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %%
# Как вы видите, по ключу response мы можем получить список, в котором хранятся словари, содержащие информацию о 
# запрошенных нами пользователях. Мы запросили информацию лишь об одном из них, поэтому список содержит только один 
# элемент. Извлечём его:

user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %%
# Метод users.get() позволяет запрашивать информацию о множестве (до 1 000) пользователей одновременно. Для этого 
# нужно использовать параметр user_ids и передавать id через запятую в строковом формате. Например, чтобы получить 
# информацию о пользователях с id=1, id=2, id=3, необходимо передать значение параметра user_ids='1,2,3'.

ids = ",".join(map(str, range(1, 501))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
# Формируем строку параметров
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bdate', 'access_token': token, 'lang': 'ru'}
# Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, 
# используя функцию pprint()
pprint(requests.get(url, params=params).json())
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'bdate': '14.2',
#                'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 4,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '18.11',
#                'can_access_closed': True,
#                'first_name': 'Илья',
#                'id': 5,
#                'is_closed': False,
#                'last_name': 'Перекопский'},
#               {'can_access_closed': True,
#                'first_name': 'Николай',
#                'id': 6,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'can_access_closed': False,
#                'first_name': 'Алексей',
#                'id': 7,
#                'is_closed': True,
#                'last_name': 'Кобылянский'},
#               {'can_access_closed': True,
#                'first_name': 'Аки',
#                'id': 8,
#                'is_closed': False,
#                'last_name': 'Сепиашвили'},
#               {'bdate': '1.1.2001',
#                'can_access_closed': False,
#                'first_name': 'Настя',
#                'id': 9,
#                'is_closed': True,
#                'last_name': 'Васильева'},
#               {'can_access_closed': False,
#                'first_name': 'Александр',
#                'id': 10,
#                'is_closed': True,
#                'last_name': 'Кузнецов'},
#               {'bdate': '18.12',
#                'can_access_closed': True,
#                'first_name': 'Михаил',
#                'id': 11,
#                'is_closed': False,
#                'last_name': 'Петров'},
#               {'bdate': '28.12',
#                'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 12,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 13,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 14,
#                'is_closed': False,
#                'last_name': 'Городецкий'},
#               {'bdate': '15.2',
#                'can_access_closed': True,
#                'first_name': 'Сергей',
#                'id': 15,
#                'is_closed': False,
#                'last_name': 'Васильков'},
#               {'can_access_closed': False,
#                'first_name': 'Виктория',
#                'id': 16,
#                'is_closed': True,
#                'last_name': 'Беспалова'},
#               {'bdate': '21.10.1982',
#                'can_access_closed': True,
#                'first_name': 'Александр',
#                'id': 17,
#                'is_closed': False,
#                'last_name': 'Беспалов'},
#               {'can_access_closed': True,
#                'first_name': 'Simon',
#                'id': 18,
#                'is_closed': False,
#                'last_name': 'Krechmer'},
#               {'bdate': '12.12',
#                'can_access_closed': True,
#                'first_name': 'Светочек',
#                'id': 19,
#                'is_closed': False,
#                'last_name': 'Аленький'},
#               {'can_access_closed': False,
#                'first_name': 'Илья',
#                'id': 20,
#                'is_closed': True,
#                'last_name': 'Турпиашвили'},
#               {'bdate': '23.7.1985',
#                'can_access_closed': True,
#                'first_name': 'Михаил',
#                'id': 21,
#                'is_closed': False,
#                'last_name': 'Равдоникас'},
#               {'bdate': '31.1.1986',
#                'can_access_closed': True,
#                'first_name': 'Семен',
#                'id': 22,
#                'is_closed': False,
#                'last_name': 'Воронин'},
#               {'bdate': '14.11',
#                'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 23,
#                'is_closed': False,
#                'last_name': 'Столбовский'},
#               {'bdate': '11.5.1986',
#                'can_access_closed': False,
#                'first_name': 'Рамми',
#                'id': 24,
#                'is_closed': True,
#                'last_name': 'Цицуашвили'},
#               {'bdate': '22.3.1984',
#                'can_access_closed': False,
#                'first_name': 'Анастасия',
#                'id': 25,
#                'is_closed': True,
#                'last_name': 'Ведущенко'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 26,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '9.1',
#                'can_access_closed': True,
#                'first_name': 'Юлия',
#                'id': 27,
#                'is_closed': False,
#                'last_name': 'Семиколенова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 28,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 29,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 30,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 31,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 32,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 33,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '2.6',
#                'can_access_closed': False,
#                'first_name': 'Татьяна',
#                'id': 34,
#                'is_closed': True,
#                'last_name': 'Плуталова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 35,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '26.1.1985',
#                'can_access_closed': True,
#                'first_name': 'Иван',
#                'id': 36,
#                'is_closed': False,
#                'last_name': 'Смирнов'},
#               {'can_access_closed': False,
#                'first_name': 'Михаил',
#                'id': 37,
#                'is_closed': True,
#                'last_name': 'Казекин'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 38,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '31.3',
#                'can_access_closed': True,
#                'first_name': 'David',
#                'id': 39,
#                'is_closed': False,
#                'last_name': 'Mirelli'},
#               {'can_access_closed': True,
#                'first_name': 'Олег',
#                'id': 40,
#                'is_closed': False,
#                'last_name': 'Чередников'},
#               {'bdate': '3.2.1986',
#                'can_access_closed': True,
#                'first_name': 'Владислав',
#                'id': 41,
#                'is_closed': False,
#                'last_name': 'Миллер'},
#               {'bdate': '20.4',
#                'can_access_closed': True,
#                'first_name': 'Сергей',
#                'id': 42,
#                'is_closed': False,
#                'last_name': 'Маркин'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 43,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '16.4',
#                'can_access_closed': True,
#                'first_name': 'Тамара',
#                'id': 44,
#                'is_closed': False,
#                'last_name': 'Мирилашвили'},
#               {'bdate': '28.1',
#                'can_access_closed': True,
#                'first_name': 'Сергей',
#                'id': 45,
#                'is_closed': False,
#                'last_name': 'Сергей'},
#               {'bdate': '14.7.1984',
#                'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 46,
#                'is_closed': False,
#                'last_name': 'Лесохин'},
#               {'bdate': '30.7.1989',
#                'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'Габриел',
#                'id': 47,
#                'is_closed': False,
#                'last_name': 'Шалел'},
#               {'can_access_closed': True,
#                'first_name': 'Миша',
#                'id': 48,
#                'is_closed': False,
#                'last_name': 'Мельников'},
#               {'bdate': '1.1',
#                'can_access_closed': True,
#                'first_name': 'Бот',
#                'id': 49,
#                'is_closed': False,
#                'last_name': 'Мороз'},
#               {'can_access_closed': True,
#                'first_name': 'Снегурочка',
#                'id': 50,
#                'is_closed': False,
#                'last_name': 'Морозова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 51,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '1.1.1982',
#                'can_access_closed': True,
#                'first_name': 'Михаил',
#                'id': 52,
#                'is_closed': False,
#                'last_name': 'Вознесенский'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 53,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '4.3',
#                'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 54,
#                'is_closed': False,
#                'last_name': 'Фуртикова'},
#               {'bdate': '24.2.1989',
#                'can_access_closed': False,
#                'first_name': 'Андрей',
#                'id': 55,
#                'is_closed': True,
#                'last_name': 'Смирнов'},
#               {'bdate': '13.5.1985',
#                'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 56,
#                'is_closed': False,
#                'last_name': 'Чернышев'},
#               {'can_access_closed': False,
#                'deactivated': 'deleted',
#                'first_name': 'Сергей',
#                'id': 57,
#                'is_closed': True,
#                'last_name': 'Владимиров'},
#               {'bdate': '3.8.1965',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Александр',
#                'id': 58,
#                'is_closed': False,
#                'last_name': 'Ковалев'},
#               {'bdate': '2.4.1985',
#                'can_access_closed': True,
#                'first_name': 'Анастасия',
#                'id': 59,
#                'is_closed': False,
#                'last_name': 'Желудкова'},
#               {'bdate': '10.5.1985',
#                'can_access_closed': False,
#                'first_name': 'Даниэль',
#                'id': 60,
#                'is_closed': True,
#                'last_name': 'Розенберг'},
#               {'bdate': '9.3.1984',
#                'can_access_closed': True,
#                'first_name': 'Григорий',
#                'id': 61,
#                'is_closed': False,
#                'last_name': 'Конрадт'},
#               {'can_access_closed': True,
#                'first_name': 'Анастасия',
#                'id': 62,
#                'is_closed': False,
#                'last_name': 'Ланина'},
#               {'can_access_closed': False,
#                'first_name': 'Никита',
#                'id': 63,
#                'is_closed': True,
#                'last_name': 'Поликарпов'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 64,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '20.7',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Mikhail',
#                'id': 65,
#                'is_closed': False,
#                'last_name': 'Torline'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 66,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 67,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '12.5.1983',
#                'can_access_closed': True,
#                'first_name': 'Вика',
#                'id': 68,
#                'is_closed': False,
#                'last_name': 'Мирилашвили'},
#               {'can_access_closed': False,
#                'first_name': 'Avi',
#                'id': 69,
#                'is_closed': True,
#                'last_name': 'Shalel'},
#               {'bdate': '14.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Митя',
#                'id': 70,
#                'is_closed': False,
#                'last_name': 'Миронов'},
#               {'bdate': '7.2',
#                'can_access_closed': False,
#                'first_name': 'Людмила',
#                'id': 71,
#                'is_closed': True,
#                'last_name': 'Романченко'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 72,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Надежда',
#                'id': 73,
#                'is_closed': True,
#                'last_name': 'Лебедева'},
#               {'bdate': '18.7.1988',
#                'can_access_closed': True,
#                'first_name': 'Наташа',
#                'id': 74,
#                'is_closed': False,
#                'last_name': 'Филимонова'},
#               {'bdate': '26.8.1988',
#                'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 75,
#                'is_closed': False,
#                'last_name': 'Копылова'},
#               {'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'David',
#                'id': 76,
#                'is_closed': False,
#                'last_name': 'Biniaurischwili'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 77,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Olivia',
#                'id': 78,
#                'is_closed': True,
#                'last_name': 'Isv'},
#               {'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Давид',
#                'id': 79,
#                'is_closed': False,
#                'last_name': 'Спектер'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 80,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '23.1',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Влад',
#                'id': 81,
#                'is_closed': False,
#                'last_name': 'Куценко'},
#               {'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Tami',
#                'id': 82,
#                'is_closed': False,
#                'last_name': 'Shalel'},
#               {'bdate': '20.6',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Дмитрий',
#                'id': 83,
#                'is_closed': False,
#                'last_name': 'Тихомиров'},
#               {'can_access_closed': True,
#                'first_name': 'Фёдор',
#                'id': 84,
#                'is_closed': False,
#                'last_name': 'Медведев'},
#               {'bdate': '23.4',
#                'can_access_closed': False,
#                'first_name': 'Mikhail',
#                'id': 85,
#                'is_closed': True,
#                'last_name': 'Gennadevich'},
#               {'bdate': '18.5',
#                'can_access_closed': False,
#                'first_name': 'Никита',
#                'id': 86,
#                'is_closed': True,
#                'last_name': 'Пиастро'},
#               {'can_access_closed': False,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 87,
#                'is_closed': True,
#                'last_name': ''},
#               {'bdate': '19.1.1988',
#                'can_access_closed': True,
#                'first_name': 'Полина',
#                'id': 88,
#                'is_closed': False,
#                'last_name': 'Олейник'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 89,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '11.6',
#                'can_access_closed': True,
#                'first_name': 'Малина',
#                'id': 90,
#                'is_closed': False,
#                'last_name': 'Baci'},
#               {'can_access_closed': True,
#                'first_name': 'Дарья',
#                'id': 91,
#                'is_closed': False,
#                'last_name': 'Белинская'},
#               {'bdate': '2.4',
#                'can_access_closed': False,
#                'first_name': 'Екатерина',
#                'id': 92,
#                'is_closed': True,
#                'last_name': 'Тихонова'},
#               {'bdate': '28.7.1984',
#                'can_access_closed': True,
#                'first_name': 'Анна',
#                'id': 93,
#                'is_closed': False,
#                'last_name': 'Забоева'},
#               {'bdate': '11.10.1982',
#                'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 94,
#                'is_closed': False,
#                'last_name': 'Теплова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 95,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 96,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 97,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 98,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '28.12.1983',
#                'can_access_closed': False,
#                'first_name': 'Наталья',
#                'id': 99,
#                'is_closed': True,
#                'last_name': 'Брагина'},
#               {'can_access_closed': True,
#                'first_name': 'Администрация ВКонтакте',
#                'id': 100,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Администратор',
#                'id': 101,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '4.8',
#                'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 102,
#                'is_closed': False,
#                'last_name': 'Тенева'},
#               {'can_access_closed': True,
#                'first_name': 'Анна',
#                'id': 103,
#                'is_closed': False,
#                'last_name': 'Романцева'},
#               {'can_access_closed': True,
#                'first_name': 'Ольга',
#                'id': 104,
#                'is_closed': False,
#                'last_name': 'Ребикова'},
#               {'bdate': '17.9',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Roman',
#                'id': 105,
#                'is_closed': False,
#                'last_name': 'Ponomarenko'},
#               {'can_access_closed': True,
#                'first_name': 'Спотти',
#                'id': 106,
#                'is_closed': False,
#                'last_name': 'Космический'},
#               {'can_access_closed': False,
#                'first_name': 'Администрация',
#                'id': 107,
#                'is_closed': True,
#                'last_name': 'Б.'},
#               {'can_access_closed': False,
#                'first_name': 'Диана',
#                'id': 108,
#                'is_closed': True,
#                'last_name': 'Курбатова'},
#               {'bdate': '22.3',
#                'can_access_closed': True,
#                'first_name': 'Ольга',
#                'id': 109,
#                'is_closed': False,
#                'last_name': 'Горюнова'},
#               {'can_access_closed': False,
#                'first_name': 'Администрация',
#                'id': 110,
#                'is_closed': True,
#                'last_name': 'В.'},
#               {'can_access_closed': True,
#                'first_name': 'Евгения',
#                'id': 111,
#                'is_closed': False,
#                'last_name': 'Лаврова'},
#               {'can_access_closed': False,
#                'first_name': 'Евгения',
#                'id': 112,
#                'is_closed': True,
#                'last_name': 'Алексеева'},
#               {'bdate': '16.2',
#                'can_access_closed': True,
#                'first_name': 'Владислав',
#                'id': 113,
#                'is_closed': False,
#                'last_name': 'Умнов'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 114,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 115,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 116,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Антон',
#                'id': 117,
#                'is_closed': False,
#                'last_name': 'Краснов'},
#               {'bdate': '17.3',
#                'can_access_closed': False,
#                'first_name': 'Светлана',
#                'id': 118,
#                'is_closed': True,
#                'last_name': 'Никулина'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 119,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '11.9.1982',
#                'can_access_closed': True,
#                'first_name': 'Елена',
#                'id': 120,
#                'is_closed': False,
#                'last_name': 'Соколова'},
#               {'bdate': '9.7.1982',
#                'can_access_closed': True,
#                'first_name': 'Надежда',
#                'id': 121,
#                'is_closed': False,
#                'last_name': 'Сторчевая'},
#               {'bdate': '2.4',
#                'can_access_closed': False,
#                'first_name': 'Надежда',
#                'id': 122,
#                'is_closed': True,
#                'last_name': 'Игошина'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 123,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '3.8.1901',
#                'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'Екатерина',
#                'id': 124,
#                'is_closed': False,
#                'last_name': 'Горбунова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 125,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 126,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 127,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 128,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 129,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 130,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Шурикен',
#                'id': 131,
#                'is_closed': True,
#                'last_name': 'Картошкин'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 132,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Николай',
#                'id': 133,
#                'is_closed': False,
#                'last_name': 'Харчев'},
#               {'bdate': '20.8.1987',
#                'can_access_closed': True,
#                'first_name': 'Илико',
#                'id': 134,
#                'is_closed': False,
#                'last_name': 'Шаптай'},
#               {'can_access_closed': True,
#                'first_name': 'Мария',
#                'id': 135,
#                'is_closed': False,
#                'last_name': 'Филатова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 136,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 137,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '7.8.1986',
#                'can_access_closed': True,
#                'first_name': 'Алексей',
#                'id': 138,
#                'is_closed': False,
#                'last_name': 'Рощин'},
#               {'bdate': '8.2.1987',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Роман',
#                'id': 139,
#                'is_closed': False,
#                'last_name': 'Чистяков'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 140,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '17.5.1983',
#                'can_access_closed': False,
#                'first_name': 'Сергей',
#                'id': 141,
#                'is_closed': True,
#                'last_name': 'Михайлов'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 142,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '16.6.1986',
#                'can_access_closed': True,
#                'first_name': 'Машечка',
#                'id': 143,
#                'is_closed': False,
#                'last_name': 'Зайцева'},
#               {'bdate': '19.5',
#                'can_access_closed': True,
#                'first_name': 'Олег',
#                'id': 144,
#                'is_closed': False,
#                'last_name': 'Зинкевич'},
#               {'bdate': '16.4.1983',
#                'can_access_closed': True,
#                'first_name': 'Константин',
#                'id': 145,
#                'is_closed': False,
#                'last_name': 'Теплов'},
#               {'bdate': '27.9.1988',
#                'can_access_closed': True,
#                'first_name': 'Александра',
#                'id': 146,
#                'is_closed': False,
#                'last_name': 'Муромцева'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 147,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '12.5',
#                'can_access_closed': True,
#                'first_name': 'Артём',
#                'id': 148,
#                'is_closed': False,
#                'last_name': 'Абанин'},
#               {'can_access_closed': True,
#                'first_name': 'Сергей',
#                'id': 149,
#                'is_closed': False,
#                'last_name': 'Лобакин'},
#               {'can_access_closed': True,
#                'first_name': 'Луиза',
#                'id': 150,
#                'is_closed': False,
#                'last_name': 'Левиева'},
#               {'bdate': '24.4.1984',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Леонид',
#                'id': 151,
#                'is_closed': False,
#                'last_name': 'Добронов'},
#               {'can_access_closed': False,
#                'first_name': 'Илара',
#                'id': 152,
#                'is_closed': True,
#                'last_name': 'Юнаева'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 153,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Елисей',
#                'id': 154,
#                'is_closed': True,
#                'last_name': 'Замахов'},
#               {'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Dennis',
#                'id': 155,
#                'is_closed': False,
#                'last_name': 'Yurlov'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 156,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 157,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '9.2.1996',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Владислав',
#                'id': 158,
#                'is_closed': False,
#                'last_name': 'Гатилов'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 159,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Васильев',
#                'id': 160,
#                'is_closed': True,
#                'last_name': 'Сергеевич'},
#               {'can_access_closed': True,
#                'first_name': 'Валентина',
#                'id': 161,
#                'is_closed': False,
#                'last_name': 'Савосина'},
#               {'bdate': '6.2',
#                'can_access_closed': True,
#                'first_name': 'Александра',
#                'id': 162,
#                'is_closed': False,
#                'last_name': 'Аленичева'},
#               {'bdate': '23.5.1986',
#                'can_access_closed': False,
#                'first_name': 'Анастасия',
#                'id': 163,
#                'is_closed': True,
#                'last_name': 'Романько'},
#               {'can_access_closed': False,
#                'first_name': 'Алексей',
#                'id': 164,
#                'is_closed': True,
#                'last_name': 'Ткаченко'},
#               {'can_access_closed': True,
#                'first_name': 'Иван',
#                'id': 165,
#                'is_closed': False,
#                'last_name': 'Романько'},
#               {'bdate': '21.3.1989',
#                'can_access_closed': True,
#                'first_name': 'Дмитрий',
#                'id': 166,
#                'is_closed': False,
#                'last_name': 'Коменденко'},
#               {'can_access_closed': True,
#                'first_name': 'Демид',
#                'id': 167,
#                'is_closed': False,
#                'last_name': 'Кириленко'},
#               {'bdate': '7.3.1982',
#                'can_access_closed': True,
#                'first_name': 'Вероника',
#                'id': 168,
#                'is_closed': False,
#                'last_name': 'Кириленко'},
#               {'bdate': '5.6.1987',
#                'can_access_closed': True,
#                'first_name': 'Ольга',
#                'id': 169,
#                'is_closed': False,
#                'last_name': 'Чистоклетова'},
#               {'can_access_closed': True,
#                'first_name': 'Богдан',
#                'id': 170,
#                'is_closed': False,
#                'last_name': 'Жидков'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 171,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '22.3.1985',
#                'can_access_closed': False,
#                'first_name': 'Алексей',
#                'id': 172,
#                'is_closed': True,
#                'last_name': 'Городецкий'},
#               {'bdate': '6.7.1984',
#                'can_access_closed': True,
#                'first_name': 'Мария',
#                'id': 173,
#                'is_closed': False,
#                'last_name': 'Чепурная'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 174,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '23.11',
#                'can_access_closed': True,
#                'first_name': 'Михаил',
#                'id': 175,
#                'is_closed': False,
#                'last_name': 'Захаренков'},
#               {'bdate': '20.5.1983',
#                'can_access_closed': True,
#                'first_name': 'Иван',
#                'id': 176,
#                'is_closed': False,
#                'last_name': 'Смирнов'},
#               {'bdate': '23.4',
#                'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 177,
#                'is_closed': False,
#                'last_name': 'Абраменко'},
#               {'can_access_closed': False,
#                'first_name': 'Марья',
#                'id': 178,
#                'is_closed': True,
#                'last_name': 'Безносова'},
#               {'can_access_closed': False,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 179,
#                'is_closed': True,
#                'last_name': ''},
#               {'bdate': '22.3.1984',
#                'can_access_closed': True,
#                'first_name': 'Владимир',
#                'id': 180,
#                'is_closed': False,
#                'last_name': 'Корнев'},
#               {'bdate': '15.8.1988',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Андрей',
#                'id': 181,
#                'is_closed': False,
#                'last_name': 'Матвеев'},
#               {'bdate': '19.5',
#                'can_access_closed': True,
#                'first_name': 'Николай',
#                'id': 182,
#                'is_closed': False,
#                'last_name': 'Андреев'},
#               {'can_access_closed': True,
#                'first_name': 'Ольга',
#                'id': 183,
#                'is_closed': False,
#                'last_name': 'Кретова'},
#               {'can_access_closed': True,
#                'first_name': 'Анастасия',
#                'id': 184,
#                'is_closed': False,
#                'last_name': 'Владимирова'},
#               {'can_access_closed': False,
#                'first_name': 'Вадим',
#                'id': 185,
#                'is_closed': True,
#                'last_name': 'Рудковский'},
#               {'bdate': '17.6',
#                'can_access_closed': False,
#                'first_name': 'Ольга',
#                'id': 186,
#                'is_closed': True,
#                'last_name': 'Савинкина-Титова'},
#               {'bdate': '27.3.1983',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Сергей',
#                'id': 187,
#                'is_closed': False,
#                'last_name': 'Воскресенкий'},
#               {'bdate': '12.12.1980',
#                'can_access_closed': False,
#                'first_name': 'Евгений',
#                'id': 188,
#                'is_closed': True,
#                'last_name': 'Лыков'},
#               {'bdate': '3.11.1983',
#                'can_access_closed': True,
#                'first_name': 'Вероника',
#                'id': 189,
#                'is_closed': False,
#                'last_name': 'Лежнева'},
#               {'can_access_closed': True,
#                'first_name': 'Вадим',
#                'id': 190,
#                'is_closed': False,
#                'last_name': 'Колосов'},
#               {'bdate': '10.2.1981',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Гена',
#                'id': 191,
#                'is_closed': False,
#                'last_name': 'Загальский'},
#               {'bdate': '1.2.1997',
#                'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 192,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '4.10.1982',
#                'can_access_closed': True,
#                'first_name': 'Иван',
#                'id': 193,
#                'is_closed': False,
#                'last_name': 'Кораблев-Дайсон'},
#               {'bdate': '24.4.1974',
#                'can_access_closed': False,
#                'first_name': 'Сергей',
#                'id': 194,
#                'is_closed': True,
#                'last_name': 'Гребнев'},
#               {'bdate': '9.3.1984',
#                'can_access_closed': True,
#                'first_name': 'Михаил',
#                'id': 195,
#                'is_closed': False,
#                'last_name': 'Келим'},
#               {'bdate': '5.1',
#                'can_access_closed': False,
#                'first_name': 'Екатерина',
#                'id': 196,
#                'is_closed': True,
#                'last_name': 'Караваева'},
#               {'can_access_closed': False,
#                'first_name': 'Дарья',
#                'id': 197,
#                'is_closed': True,
#                'last_name': 'Бондаренко'},
#               {'bdate': '3.5',
#                'can_access_closed': False,
#                'first_name': 'Вальтер',
#                'id': 198,
#                'is_closed': True,
#                'last_name': 'Киршнер'},
#               {'can_access_closed': False,
#                'first_name': 'Елена',
#                'id': 199,
#                'is_closed': True,
#                'last_name': 'Жигалова'},
#               {'bdate': '12.7.1983',
#                'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 200,
#                'is_closed': False,
#                'last_name': 'Стрельников'},
#               {'bdate': '3.10.1983',
#                'can_access_closed': True,
#                'first_name': 'Игнатий',
#                'id': 201,
#                'is_closed': False,
#                'last_name': 'Дьяков'},
#               {'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Максим',
#                'id': 202,
#                'is_closed': False,
#                'last_name': 'Ластовка'},
#               {'bdate': '9.10',
#                'can_access_closed': True,
#                'first_name': 'Зоя',
#                'id': 203,
#                'is_closed': False,
#                'last_name': 'Барабанова'},
#               {'can_access_closed': True,
#                'first_name': 'Юлия',
#                'id': 204,
#                'is_closed': False,
#                'last_name': 'Скрябина'},
#               {'bdate': '26.8',
#                'can_access_closed': False,
#                'first_name': 'Ирина',
#                'id': 205,
#                'is_closed': True,
#                'last_name': 'Ямщикова'},
#               {'bdate': '12.7.1983',
#                'can_access_closed': True,
#                'first_name': 'Юрий',
#                'id': 206,
#                'is_closed': False,
#                'last_name': 'Скрелин'},
#               {'bdate': '18.1.1983',
#                'can_access_closed': True,
#                'first_name': 'Yulia',
#                'id': 207,
#                'is_closed': False,
#                'last_name': 'Bekmukhamedova'},
#               {'bdate': '30.11',
#                'can_access_closed': False,
#                'first_name': 'Гена',
#                'id': 208,
#                'is_closed': True,
#                'last_name': 'Зарохин'},
#               {'bdate': '21.9.1984',
#                'can_access_closed': True,
#                'first_name': 'Елена',
#                'id': 209,
#                'is_closed': False,
#                'last_name': 'Дьячкова'},
#               {'bdate': '23.9.1984',
#                'can_access_closed': True,
#                'first_name': 'Аня',
#                'id': 210,
#                'is_closed': False,
#                'last_name': 'Дормидонтова'},
#               {'bdate': '21.2',
#                'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 211,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '19.4',
#                'can_access_closed': True,
#                'first_name': 'Алёна',
#                'id': 212,
#                'is_closed': False,
#                'last_name': 'Фёдорова'},
#               {'can_access_closed': False,
#                'first_name': 'Максим',
#                'id': 213,
#                'is_closed': True,
#                'last_name': 'Казанский'},
#               {'bdate': '15.8.1994',
#                'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 214,
#                'is_closed': False,
#                'last_name': 'Зелёный'},
#               {'bdate': '4.8',
#                'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 215,
#                'is_closed': False,
#                'last_name': 'Мерзлякова'},
#               {'bdate': '8.9.1987',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Андрей',
#                'id': 216,
#                'is_closed': False,
#                'last_name': 'Мирных'},
#               {'bdate': '18.4',
#                'can_access_closed': True,
#                'first_name': 'Alexander',
#                'id': 217,
#                'is_closed': False,
#                'last_name': 'Nasyrov'},
#               {'bdate': '21.9',
#                'can_access_closed': True,
#                'first_name': 'Oksana',
#                'id': 218,
#                'is_closed': False,
#                'last_name': 'Zotova'},
#               {'bdate': '22.3',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Роман',
#                'id': 219,
#                'is_closed': False,
#                'last_name': 'Акамёлков'},
#               {'bdate': '14.11',
#                'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 220,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '23.1',
#                'can_access_closed': True,
#                'first_name': 'Наталья',
#                'id': 221,
#                'is_closed': False,
#                'last_name': 'Курчакова'},
#               {'bdate': '28.7',
#                'can_access_closed': False,
#                'first_name': 'Анна',
#                'id': 222,
#                'is_closed': True,
#                'last_name': 'Ступина'},
#               {'can_access_closed': True,
#                'first_name': 'Инга',
#                'id': 223,
#                'is_closed': False,
#                'last_name': 'Гладущик'},
#               {'bdate': '15.6.1983',
#                'can_access_closed': False,
#                'first_name': 'Ирина',
#                'id': 224,
#                'is_closed': True,
#                'last_name': 'Кирсанова'},
#               {'bdate': '15.6',
#                'can_access_closed': True,
#                'first_name': 'Елена',
#                'id': 225,
#                'is_closed': False,
#                'last_name': 'Петропавловская'},
#               {'can_access_closed': False,
#                'first_name': 'Антон',
#                'id': 226,
#                'is_closed': True,
# ...
#                'is_closed': True,
#                'last_name': 'Коновалова'},
#               {'bdate': '6.4',
#                'can_access_closed': True,
#                'first_name': 'Алена',
#                'id': 427,
#                'is_closed': False,
#                'last_name': 'Матвейчук'},
#               {'bdate': '17.11.1987',
#                'can_access_closed': False,
#                'first_name': 'Александр',
#                'id': 428,
#                'is_closed': True,
#                'last_name': 'Кирпичников'},
#               {'can_access_closed': True,
#                'first_name': 'Михаил',
#                'id': 429,
#                'is_closed': False,
#                'last_name': 'Зубков'},
#               {'can_access_closed': True,
#                'first_name': 'Piotr',
#                'id': 430,
#                'is_closed': False,
#                'last_name': 'Gr'},
#               {'bdate': '14.11.1985',
#                'can_access_closed': False,
#                'first_name': 'Мария',
#                'id': 431,
#                'is_closed': True,
#                'last_name': 'Ажинова'},
#               {'bdate': '7.2.1905',
#                'can_access_closed': False,
#                'first_name': 'Ný',
#                'id': 432,
#                'is_closed': True,
#                'last_name': 'Lero'},
#               {'bdate': '28.6.1989',
#                'can_access_closed': True,
#                'first_name': 'Анастасия',
#                'id': 433,
#                'is_closed': False,
#                'last_name': 'Мальмрус'},
#               {'bdate': '2.6.1985',
#                'can_access_closed': True,
#                'first_name': 'Сергей',
#                'id': 434,
#                'is_closed': False,
#                'last_name': 'Золотонос'},
#               {'bdate': '1.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Константин',
#                'id': 435,
#                'is_closed': False,
#                'last_name': 'Паблопикассович'},
#               {'bdate': '19.6.1986',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Сергей',
#                'id': 436,
#                'is_closed': False,
#                'last_name': 'Дюжев'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 437,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Сергей',
#                'id': 438,
#                'is_closed': False,
#                'last_name': 'Шипилов'},
#               {'can_access_closed': True,
#                'first_name': 'Тимофей',
#                'id': 439,
#                'is_closed': False,
#                'last_name': 'Стороженко'},
#               {'bdate': '14.5',
#                'can_access_closed': True,
#                'first_name': 'Anastasia',
#                'id': 440,
#                'is_closed': False,
#                'last_name': 'Balashova'},
#               {'bdate': '26.12.1988',
#                'can_access_closed': True,
#                'first_name': 'Евгения',
#                'id': 441,
#                'is_closed': False,
#                'last_name': 'Нигматуллина'},
#               {'bdate': '7.7',
#                'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 442,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '3.11.1984',
#                'can_access_closed': False,
#                'first_name': 'Алексей',
#                'id': 443,
#                'is_closed': True,
#                'last_name': 'Юрецкий'},
#               {'bdate': '5.2',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Алиса',
#                'id': 444,
#                'is_closed': False,
#                'last_name': 'Иванова'},
#               {'bdate': '21.6',
#                'can_access_closed': True,
#                'first_name': 'Филипп',
#                'id': 445,
#                'is_closed': False,
#                'last_name': 'Рамбов'},
#               {'bdate': '26.8.1983',
#                'can_access_closed': True,
#                'first_name': 'Владимир',
#                'id': 446,
#                'is_closed': False,
#                'last_name': 'Богданов'},
#               {'can_access_closed': True,
#                'first_name': 'Marianna',
#                'id': 447,
#                'is_closed': False,
#                'last_name': 'Demenkova'},
#               {'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Никита',
#                'id': 448,
#                'is_closed': False,
#                'last_name': 'Аникеев'},
#               {'bdate': '21.2.1985',
#                'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 449,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '27.7',
#                'can_access_closed': True,
#                'first_name': 'Марина',
#                'id': 450,
#                'is_closed': False,
#                'last_name': 'Требина'},
#               {'bdate': '15.10',
#                'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 451,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '27.6.1986',
#                'can_access_closed': True,
#                'first_name': 'Олег',
#                'id': 452,
#                'is_closed': False,
#                'last_name': 'Желтянников'},
#               {'bdate': '8.10.1983',
#                'can_access_closed': True,
#                'first_name': 'Ярославна',
#                'id': 453,
#                'is_closed': False,
#                'last_name': 'Гаген-Торн'},
#               {'bdate': '29.1.1986',
#                'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 454,
#                'is_closed': False,
#                'last_name': 'Гук'},
#               {'bdate': '18.7.1977',
#                'can_access_closed': False,
#                'first_name': 'Евгений',
#                'id': 455,
#                'is_closed': True,
#                'last_name': 'Шехтер'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 456,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Владимир',
#                'id': 457,
#                'is_closed': False,
#                'last_name': 'Баранов'},
#               {'can_access_closed': True,
#                'first_name': 'Сергей',
#                'id': 458,
#                'is_closed': False,
#                'last_name': 'Нагапетян'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 459,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Ilya',
#                'id': 460,
#                'is_closed': False,
#                'last_name': 'Dneprovsky'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 461,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 462,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '22.2.1984',
#                'can_access_closed': True,
#                'first_name': 'Людмила',
#                'id': 463,
#                'is_closed': False,
#                'last_name': 'Захарова'},
#               {'bdate': '8.1',
#                'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 464,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 465,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Anastasia',
#                'id': 466,
#                'is_closed': False,
#                'last_name': 'Mikhaylova'},
#               {'bdate': '11.12',
#                'can_access_closed': True,
#                'first_name': 'Игорь',
#                'id': 467,
#                'is_closed': False,
#                'last_name': 'Перекопский'},
#               {'bdate': '3.4.1985',
#                'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Паша',
#                'id': 468,
#                'is_closed': False,
#                'last_name': 'Кипелов'},
#               {'bdate': '22.12',
#                'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 469,
#                'is_closed': False,
#                'last_name': 'Пушкина'},
#               {'can_access_closed': True,
#                'first_name': 'Антон',
#                'id': 470,
#                'is_closed': False,
#                'last_name': 'Зайцев'},
#               {'can_access_closed': True,
#                'first_name': 'Дмитрий',
#                'id': 471,
#                'is_closed': False,
#                'last_name': 'Никончук'},
#               {'can_access_closed': True,
#                'first_name': 'Евгения',
#                'id': 472,
#                'is_closed': False,
#                'last_name': 'Захарова'},
#               {'bdate': '11.11',
#                'can_access_closed': True,
#                'first_name': 'Алёна',
#                'id': 473,
#                'is_closed': False,
#                'last_name': 'Тайлер'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 474,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 475,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Лена',
#                'id': 476,
#                'is_closed': True,
#                'last_name': 'Самуйлова'},
#               {'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Алексей',
#                'id': 477,
#                'is_closed': False,
#                'last_name': 'Комаров'},
#               {'bdate': '25.8.1985',
#                'can_access_closed': False,
#                'first_name': 'Кирилл',
#                'id': 478,
#                'is_closed': True,
#                'last_name': 'Мошков'},
#               {'bdate': '23.4.1989',
#                'can_access_closed': True,
#                'first_name': 'Виктория',
#                'id': 479,
#                'is_closed': False,
#                'last_name': 'Стацевич'},
#               {'can_access_closed': False,
#                'first_name': 'Yarik',
#                'id': 480,
#                'is_closed': True,
#                'last_name': 'Markov'},
#               {'can_access_closed': True,
#                'first_name': 'Софья',
#                'id': 481,
#                'is_closed': False,
#                'last_name': 'Чебанова'},
#               {'bdate': '7.2.1983',
#                'can_access_closed': True,
#                'first_name': 'Юлия',
#                'id': 482,
#                'is_closed': False,
#                'last_name': 'Васильева'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 483,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '2.7.1987',
#                'can_access_closed': True,
#                'first_name': 'Юлия',
#                'id': 484,
#                'is_closed': False,
#                'last_name': 'Нураева'},
#               {'can_access_closed': True,
#                'deactivated': 'banned',
#                'first_name': 'Дарья',
#                'id': 485,
#                'is_closed': False,
#                'last_name': 'Павлова'},
#               {'bdate': '15.1',
#                'can_access_closed': False,
#                'first_name': 'Наталия',
#                'id': 486,
#                'is_closed': True,
#                'last_name': 'Шабанова'},
#               {'bdate': '31.7.1984',
#                'can_access_closed': False,
#                'first_name': 'Светлана',
#                'id': 487,
#                'is_closed': True,
#                'last_name': 'Каткова'},
#               {'can_access_closed': True,
#                'first_name': 'Алексей',
#                'id': 488,
#                'is_closed': False,
#                'last_name': 'Леонидович'},
#               {'bdate': '24.10.1988',
#                'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 489,
#                'is_closed': True,
#                'last_name': 'Родионова'},
#               {'bdate': '30.11',
#                'can_access_closed': False,
#                'deactivated': 'deleted',
#                'first_name': 'Елена',
#                'id': 490,
#                'is_closed': True,
#                'last_name': 'Ящике'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 491,
#                'is_closed': False,
#                'last_name': ''},
#               {'bdate': '12.7.1988',
#                'can_access_closed': True,
#                'first_name': 'Кирилл',
#                'id': 492,
#                'is_closed': False,
#                'last_name': 'Ширяев'},
#               {'bdate': '8.5.1985',
#                'can_access_closed': True,
#                'first_name': 'Дарья',
#                'id': 493,
#                'is_closed': False,
#                'last_name': 'Монихарт'},
#               {'bdate': '27.12',
#                'can_access_closed': False,
#                'first_name': 'Анна',
#                'id': 494,
#                'is_closed': True,
#                'last_name': 'Бабурова'},
#               {'bdate': '24.12.1988',
#                'can_access_closed': False,
#                'first_name': 'Михаил',
#                'id': 495,
#                'is_closed': True,
#                'last_name': 'Кадобнов'},
#               {'bdate': '30.12.1989',
#                'can_access_closed': True,
#                'first_name': 'Григорий',
#                'id': 496,
#                'is_closed': False,
#                'last_name': 'Малыгин'},
#               {'bdate': '10.7.1988',
#                'can_access_closed': False,
#                'first_name': 'Светлана',
#                'id': 497,
#                'is_closed': True,
#                'last_name': 'Лапина'},
#               {'can_access_closed': False,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 498,
#                'is_closed': True,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 499,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Анонимный пользователь',
#                'id': 500,
#                'is_closed': False,
#                'last_name': ''}]}

# %%
# Используя API, определите долю женщин (sex=1) среди пользователей с id от 1 до 500. Иногда будут попадаться 
# пользователи, у которых пол не указан (sex=0), — таких пользователей не нужно учитывать в общем числе.

import requests
url = 'https://api.vk.com/method/users.get'
ids = ",".join(map(str, range(1, 501)))
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'}
response = requests.get(url, params=params).json()['response']
men=women=0
for elem in response:
    if elem['sex'] == 2:
        men+=1
    elif elem['sex'] == 1:
        women+=1
    else:
        continue
print(round(women/(men+women),2))
# Out:
# 0.49

# %%
# для получения списка пользователей группы доступен метод groups.getMembers.
# Согласно документации, обязательным параметром данного метода является group_id — идентификатор, или короткое 
# имя, группы. В нашем случае это vk: https://vk.com/vk. Протестируем, как работает метод в самом простом 
# случае, — получим id участников группы:

import requests # Импортируем модуль requests
token = '1e3c445f1e3c445f1e3c445f7b1d2b10c811e3c1e3c445f7be8fe4d9961f0eccdb46c54' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# {'response': {'count': 13457365, 'items': [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 421, 431, 450, 467, 485, 510, 550, 619, 640, 690, 702, 721, 804, 809, 831, 832, 834, 847, 900, 905, 907, 914, 930, 943, 952, 958, 966, 976, 979, 997, 1000, 1018, 1023, 1032, 1033, 1038, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1301, 1333, 1334, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1503, 1531, 1550, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1869, 1887, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2136, 2150, 2195, 2201, 2230, 2236, 2273, 2281, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2513, 2515, 2539, 2571, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2909, 2919, 2922, 2932, 2953, 2962, 2982, 3001, 3006, 3041, 3130, 3135, 3172, 3186, 3203, 3231, 3250, 3254, 3316, 3320, 3321, 3328, 3331, 3332, 3364, 3372, 3373, 3384, 3388, 3402, 3420, 3422, 3427, 3436, 3450, 3458, 3472, 3483, 3486, 3491, 3492, 3520, 3545, 3556, 3581, 3626, 3637, 3646, 3653, 3657, 3658, 3675, 3684, 3690, 3697, 3719, 3786, 3820, 3824, 3836, 3837, 3851, 3863, 3904, 3909, 3938, 3948, 3979, 4004, 4010, 4023, 4026, 4041, 4047, 4048, 4108, 4130, 4150, 4157, 4169, 4189, 4192, 4236, 4262, 4282, 4326, 4378, 4439, 4440, 4447, 4485, 4505, 4521, 4528, 4530, 4537, 4543, 4554, 4558, 4563, 4564, 4583, 4599, 4601, 4640, 4668, 4669, 4670, 4672, 4689, 4693, 4728, 4731, 4748, 4754, 4767, 4769, 4790, 4818, 4828, 4857, 4862, 4866, 4881, 4921, 4923, 4928, 4947, 4981, 5011, 5017, 5067, 5073, 5161, 5166, 5183, 5251, 5262, 5273, 5280, 5286, 5354, 5386, 5387, 5392, 5394, 5399, 5401, 5430, 5432, 5436, 5438, 5472, 5527, 5546, 5547, 5585, 5590, 5597, 5606, 5615, 5629, 5634, 5665, 5701, 5733, 5768, 5775, 5793, 5803, 5819, 5846, 5850, 5896, 5914, 5916, 5932, 5944, 5959, 5965, 5968, 5990, 5991, 5993, 5997, 6000, 6021, 6037, 6046, 6086, 6099, 6107, 6111, 6154, 6161, 6167, 6181, 6186, 6187, 6203, 6260, 6265, 6293, 6323, 6333, 6339, 6379, 6380, 6390, 6440, 6492, 6520, 6547, 6557, 6564, 6595, 6604, 6627, 6635, 6670, 6683, 6689, 6701, 6703, 6709, 6715, 6797, 6801, 6862, 6960, 6994, 7012, 7040, 7047, 7050, 7052, 7068, 7099, 7112, 7115, 7117, 7126, 7141, 7188, 7200, 7208, 7226, 7227, 7286, 7290, 7338, 7402, 7404, 7408, 7428, 7451, 7481, 7492, 7500, 7525, 7543, 7547, 7557, 7595, 7615, 7652, 7661, 7725, 7737, 7755, 7768, 7777, 7830, 7847, 7855, 7858, 7860, 7962, 7982, 7998, 8019, 8069, 8080, 8093, 8149, 8151, 8156, 8157, 8166, 8167, 8181, 8182, 8194, 8195, 8201, 8224, 8266, 8273, 8298, 8310, 8321, 8323, 8347, 8348, 8377, 8398, 8418, 8422, 8436, 8443, 8479, 8484, 8505, 8518, 8536, 8544, 8576, 8610, 8636, 8642, 8656, 8658, 8704, 8718, 8727, 8738, 8752, 8777, 8792, 8813, 8875, 8883, 8909, 8910, 8937, 8959, 9000, 9014, 9016, 9018, 9079, 9095, 9100, 9110, 9111, 9115, 9173, 9187, 9189, 9222, 9246, 9256, 9352, 9399, 9408, 9412, 9413, 9435, 9444, 9447, 9450, 9459, 9466, 9499, 9527, 9532, 9536, 9547, 9556, 9566, 9569, 9571, 9579, 9699, 9723, 9737, 9741, 9748, 9775, 9778, 9782, 9847, 9894, 9900, 9954, 9971, 9981, 9993, 10010, 10090, 10162, 10217, 10272, 10284, 10286, 10302, 10350, 10351, 10354, 10365, 10366, 10376, 10516, 10518, 10570, 10596, 10607, 10615, 10621, 10639, 10682, 10697, 10741, 10749, 10767, 10811, 10833, 10887, 10919, 10955, 10956, 10961, 10972, 10999, 11027, 11064, 11068, 11081, 11084, 11150, 11187, 11191, 11236, 11243, 11271, 11303, 11420, 11446, 11451, 11483, 11568, 11649, 11723, 11727, 11747, 11754, 11763, 11768, 11782, 11865, 11964, 11983, 12005, 12029, 12036, 12097, 12133, 12150, 12159, 12172, 12213, 12252, 12255, 12264, 12316, 12325, 12332, 12345, 12353, 12367, 12407, 12441, 12448, 12454, 12456, 12473, 12477, 12545, 12560, 12570, 12617, 12637, 12638, 12707, 12716, 12718, 12736, 12748, 12756, 12762, 12803, 12808, 12 ...

# %%
# По ключу count мы можем получить общее число участников группы, а список по ключу items хранит их id. Посмотрим на 
# него поближе:

print(len(data['response']['items'])) # Выводим на экран количество элементов словаря
# Out:
# 1000

# %%
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки получить информацию о 1000 пользователей, 
# чтобы мы могли сверить результат выгрузки из 20 пользователей:

users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) # Выводим перечень id первых 20 пользователей
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 421, 431, 450, 467, 485, 510, 550]

# %%
# Теперь используем count и offset, чтобы получить те же id по пять за раз:

import requests # Импортируем модуль requests
token = '1e3c445f1e3c445f1e3c445f7b1d2b10c811e3c1e3c445f7be8fe4d9961f0eccdb46c54' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 421, 431, 450, 467, 485, 510, 550]

# %%
# Сравним списки, полученные двумя способами:

print(user_ids == users_for_checking)
# Out:
# True

# %%
# Так как результат сравнения — True, списки идентичны. Значит, второй способ работает корректно. Теперь мы можем 
# получить данные обо всех пользователях, выставив count = 1000 и max_count = data['response']['count'].

# %%
# Воспользуемся библиотекой time и методом sleep, с помощью которого мы можем добавить паузу, например в 0.5 секунд, 
# после каждого запроса:

import requests # Импортируем модуль requests
import time # Импортируем модуль time
token = '1e3c445f1e3c445f1e3c445f7b1d2b10c811e3c1e3c445f7be8fe4d9961f0eccdb46c54' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %%
# Для получения информации о сообщениях на стене в API ВКонтакте предусмотрен метод wall.get. Применим его:

import requests # Импортируем модуль requests
from pprint import pprint # Импортируем функцию pprint()
token = '1e3c445f1e3c445f1e3c445f7b1d2b10c811e3c1e3c445f7be8fe4d9961f0eccdb46c54' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 690,
#               'items': [{'attachments': [{'photo': {'access_key': 'a34be7e861be7dce43',
#                                                     'album_id': -7,
#                                                     'date': 1708517042,
#                                                     'id': 457346856,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1461677,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=130x130&quality=96&sign=faf26689a0866d04be904d00393bafb7&c_uniq_tag=VSlj9Y7JURFx21teIR6dlfIvwQBfEMXljWRvNQ4YL3M&type=album',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=130x130&quality=96&sign=faf26689a0866d04be904d00393bafb7&c_uniq_tag=VSlj9Y7JURFx21teIR6dlfIvwQBfEMXljWRvNQ4YL3M&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=200x200&quality=96&sign=16b2ef1d30033ba6ee4abf7c04f3f9d6&c_uniq_tag=WhFUpvFCZirCyFkq7-DguijDNasFPPW47Dy2P-vV3Ws&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=320x320&quality=96&sign=8b082f8aad764a79a43fceacf9cca1bd&c_uniq_tag=jDRs5UPvrPcZ6oJYf7Ert8tGeDNkG68RfoTqHByscxM&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=510x510&quality=96&sign=b748e0275761094a91e5fb692b57898d&c_uniq_tag=ZbzXpdYeSaDbo4tHJFY_PH3UyPLcg3bbO8LJx_SWFhk&type=album',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=75x75&quality=96&sign=619f77933e9d5ffc10d91f50548292c4&c_uniq_tag=Oe10bxC63HI7rvw87wbJjagkQt2-VGvClmGCGd3nMcw&type=album',
#                                                                'width': 75},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=604x604&quality=96&sign=780acef83aa31eaa906d4fe2b27351cf&c_uniq_tag=3cgsebGqMOU6WdwB_-fiGIsAKblqWPZ_kbya3aIqw0c&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=807x807&quality=96&sign=49b0dac24956b3026af5581acc6f4d5b&c_uniq_tag=vyhFH9mkt6jYdsIfxswJPUem98t6OWSj0OB1NvhwVs8&type=album',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=1080x1080&quality=96&sign=f2bf3703ab0eabec7f68062c38230834&c_uniq_tag=fVVOim8C6T-ZvfyaRKyEbLKx63RfDlH7sXghlMH395c&type=album',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'e2af357ee2593612b6'},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 113,
#                                       'groups_can_post': True},
#                          'date': 1708517100,
#                          'from_id': -22822305,
#                          'hash': 'x29fSzdpVUr9hx0qzg',
#                          'id': 1461677,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1493,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 137, 'user_reposted': 0},
#                          'text': 'А это всегда приятно!',
#                          'type': 'post',
#                          'views': {'count': 353915}},
#                         {'attachments': [],
#                          'comments': {'can_post': 1,
#                                       'count': 267,
#                                       'groups_can_post': True},
#                          'date': 1708344300,
#                          'from_id': -22822305,
#                          'hash': 'acq7bmTkX76qGV9p9A',
#                          'id': 1461279,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 302,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 32, 'user_reposted': 0},
#                          'text': 'А похвастайтесь своими результатами в '
#                                  '«Шагах»!\n'
#                                  '\n'
#                                  'С телефона заходим '
#                                  '[https://vk.com/app7539087_9849589|сюда], '
#                                  'делаем скриншот, скидываем в комментарии 👇',
#                          'type': 'post',
#                          'views': {'count': 360518}},
#                         {'attachments': [{'photo': {'access_key': '3548e48fbc1f67faf3',
#                                                     'album_id': -7,
#                                                     'date': 1707996203,
#                                                     'id': 457346700,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1460705,
#                                                     'sizes': [{'height': 114,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=130x114&quality=96&sign=5669913c6e989a7215dda6a0ec06e786&c_uniq_tag=EvcYpO2YWLNGcgpuAoYR-0dKBPzkopotM2vAAWW2dUk&type=album',
#                                                                'width': 130},
#                                                               {'height': 114,
#                                                                'type': 'o',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=130x114&quality=96&sign=5669913c6e989a7215dda6a0ec06e786&c_uniq_tag=EvcYpO2YWLNGcgpuAoYR-0dKBPzkopotM2vAAWW2dUk&type=album',
#                                                                'width': 130},
#                                                               {'height': 176,
#                                                                'type': 'p',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=200x176&quality=96&sign=d5607df50e66779512fc63776b12c980&c_uniq_tag=5nUC_5xZqA7rb_eztmQ3hXkZmzygGZI-MNMHeU4oY84&type=album',
#                                                                'width': 200},
#                                                               {'height': 281,
#                                                                'type': 'q',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=320x281&quality=96&sign=5e4ca1ffd7a9b93036c3e522206b612f&c_uniq_tag=xXx31fnCAoyjtqyinJho3caAeFSW0GTTjhYz5TFmkIQ&type=album',
#                                                                'width': 320},
#                                                               {'height': 448,
#                                                                'type': 'r',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=510x448&quality=96&sign=406d932859e6f8f3c1acd860d5bbfd9b&c_uniq_tag=jpf42OgZAoIaD-CzZYhXGmS-gJJEQWf_4zJKPkf0BTM&type=album',
#                                                                'width': 510},
#                                                               {'height': 66,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=75x66&quality=96&sign=5b283ea1700ad0e99abb5cb518127249&c_uniq_tag=NbUXOJyI1l6388hcO9NP7Rb_kaXcfx4-r1lQXa7HUQk&type=album',
#                                                                'width': 75},
#                                                               {'height': 1125,
#                                                                'type': 'w',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=1280x1125&quality=96&sign=8fbb48fcd994bc48a9a59ed20a1757ac&c_uniq_tag=gntQZXa4MBdM9CTzAuw_RPJhTCrXNpe0uX0XFF2XUSc&type=album',
#                                                                'width': 1280},
#                                                               {'height': 531,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=604x531&quality=96&sign=a18333d3737519fc020f892e70db01f7&c_uniq_tag=55RD7kOaiNICmjCiDSmNROJKSOhCqnsac6QZfi2JyF8&type=album',
#                                                                'width': 604},
#                                                               {'height': 709,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=807x709&quality=96&sign=7bcaf19377f0b713d2a2c9b47142961e&c_uniq_tag=yj-YRdzPVus9knEQiQIJVEye8SBdwjJUqtrxgiy_Sbg&type=album',
#                                                                'width': 807},
#                                                               {'height': 1125,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-22.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=1280x1125&quality=96&sign=8fbb48fcd994bc48a9a59ed20a1757ac&c_uniq_tag=gntQZXa4MBdM9CTzAuw_RPJhTCrXNpe0uX0XFF2XUSc&type=album',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'a51f89cfabe26c36ee'},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 455,
#                                       'groups_can_post': True},
#                          'date': 1707996601,
#                          'from_id': -22822305,
#                          'hash': 'ho9uoBR6hiUjgDbtew',
#                          'id': 1460705,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 401,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 72, 'user_reposted': 0},
#                          'text': 'ВКонтакте появился [vk.com/safety|Центр '
#                                  'цифрового комфорта].\n'
#                                  '\n'
#                                  'В нём собраны рекомендации по поддержке '
#                                  'ментального здоровья, советы по поведению в '
#                                  'сложных ситуациях и тематические новости. '
#                                  'Например, можно узнать, как '
#                                  'противодействовать вражде и травле, как '
#                                  'распознать злоумышленника и как работает '
#                                  'модерация ВКонтакте.\n'
#                                  '\n'
#                                  'Материалы мы готовили вместе с экспертами '
#                                  'благотворительного фонда '
#                                  '[https://vk.com/shalash.academy|«Шалаш»]. '
#                                  'Его сотрудники помогают детям, родителям и '
#                                  'учителям справляться с проявлениями '
#                                  'агрессии.\n'
#                                  '\n'
#                                  'В Центре цифрового комфорта будут регулярно '
#                                  'публиковаться свежие материалы. Найти его '
#                                  'можно под боковым меню во вкладке «Ещё», '
#                                  'если заходить ВКонтакте с компьютера, и по '
#                                  'прямой [vk.com/safety|ссылке] в приложении '
#                                  'для iOS и Android.',
#                          'type': 'post',
#                          'views': {'count': 241034}},
#                         {'attachments': [{'photo': {'access_key': '8fef3e9e18e97d2626',
#                                                     'album_id': -7,
#                                                     'date': 1707908176,
#                                                     'id': 457346651,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1460426,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-22.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=130x130&quality=96&sign=44797a3ef821328546b92cb64e85b037&c_uniq_tag=dxQ_pe6qpxg0_okhXt8R35O1dpwXuLoD6hS_HlspQvg&type=album',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun6-22.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=130x130&quality=96&sign=44797a3ef821328546b92cb64e85b037&c_uniq_tag=dxQ_pe6qpxg0_okhXt8R35O1dpwXuLoD6hS_HlspQvg&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun6-22.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=200x200&quality=96&sign=2534f6fc2b3f4f9311af975a769169bc&c_uniq_tag=jyRouLUKHl-hV5PrBF2g_omIZfq0qnx8WmDf5KV3lRQ&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun6-22.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=320x320&quality=96&sign=8ef7800c0c58ecb1d61cf1ba29828a44&c_uniq_tag=txONf9QJ3A85JeaXGo5GjOHVLJZkzNBWSlphdVeXUsY&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun6-22.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=510x510&quality=96&sign=cbf5b4351a78fc99aa490dde3e8bc5c7&c_uniq_tag=X7IFoT1kl97gHPfjp21XW4lyuhBwS8DceL1AYLLlU4g&type=album',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-22.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=75x75&quality=96&sign=94eba2b474f4d7bfaabbde6a1a159a6e&c_uniq_tag=j_DBvqT41BzbhGeTXqf1yWj2tCLRFuAIQjLKUXVSINI&type=album',
#                                                                'width': 75},
#                                                               {'height': 1500,
#                                                                'type': 'w',
#                                                                'url': 'https://sun6-22.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=1500x1500&quality=96&sign=2f525a9d7433198c9bf7b3689430d075&c_uniq_tag=22emjBUPkJULp4eS77ynrgBv8y7v6SR40uCg6fXSzjk&type=album',
#                                                                'width': 1500},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-22.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=604x604&quality=96&sign=8c03a23063dca976c1b26ca85d6d9f62&c_uniq_tag=N6kjsRdXFOIvdJW8VV2M-RACrOu1rLX0AfR09cNkk0I&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-22.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=807x807&quality=96&sign=c1f3f2772a3271f2e9537f8b923b1a0a&c_uniq_tag=Z5RI8UealwzXUxplYTVLSiFyLNFzAxixkRGLEISXFyE&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-22.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=1280x1280&quality=96&sign=80ad8e18d41c165933a117daf9e90151&c_uniq_tag=qCmGWCTouN3NdRejXy7cXfWoKXcE9k00RhetW-_RXUQ&type=album',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '24ce125044954ac9e5'},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 250,
#                                       'groups_can_post': True},
#                          'date': 1707908176,
#                          'from_id': -22822305,
#                          'hash': 'KlDqWpVNxUjI9xUSeg',
#                          'id': 1460426,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 443,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 39, 'user_reposted': 0},
#                          'text': 'Всех с Днём влюблённых! 💙\n'
#                                  '\n'
#                                  'Надеемся, вы проводите его вместе со своей '
#                                  'второй половинкой. А если второй половинки '
#                                  'пока нет, то загляните в '
#                                  '[https://vk.com/dating|VK Знакомства], она '
#                                  'наверняка там!\n'
#                                  '\n'
#                                  'Кстати, в VK Знакомствах появились '
#                                  'дополнительные отметки. Всем, кто их '
#                                  'установит, станут доступны премиум-функции в '
#                                  'подарок, а ещё с этими отметками можно '
#                                  'принять участие в розыгрыше свиданий на '
#                                  'катке в [https://vk.com/vkdating|сообществе] '
#                                  'VK Знакомств.\n'
#                                  '\n'
#                                  'И это не всё! Вот что ещё мы для вас '
#                                  'подготовили:\n'
#                                  '\n'
#                                  '💙VK Клипы проведут '
#                                  '[https://vk.com/video-194351072_456241811|прямую '
#                                  'трансляцию] с клипером Кариной Мурашкиной. В '
#                                  'течение часа ведущая будет делать '
#                                  'пользователям предсказания на коротких '
#                                  'роликах.\n'
#                                  '\n'
#                                  '💙 В «Шагах» появился вызов '
#                                  '[https://vk.com/steps#challengeAAAAAAAAAAAABXAPAEAAAAAAAA&ref=copy_link&ref_id=11143326&sharing_id=By4ffCW4ugXc|«Навстречу '
#                                  'любви»].\n'
#                                  '\n'
#                                  '💙 И не забываем про '
#                                  '[https://vk.com/app6851096|«Коробку для '
#                                  'валентинок»]! Отправьте кому-нибудь тёплое '
#                                  'пожелание. Быть может, симпатия окажется '
#                                  'взаимной, и это 14 февраля станет '
#                                  'по-настоящему особенным!',
#                          'type': 'post',
#                          'views': {'count': 247392}},
#                         {'attachments': [{'photo': {'access_key': 'ca0c9c1abe6d80be6f',
#                                                     'album_id': -7,
#                                                     'date': 1707490737,
#                                                     'id': 457346590,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-20.userapi.com/impg/hkijg-fGyhQ7KfZHM9hZGWJWGgLmwsD8PNqsLw/V6ncES1Y2hI.jpg?size=130x130&quality=96&sign=7822c0a71e6783098e750959e82f3eae&c_uniq_tag=1oMLBZw_ewKuo6WcT7bBD75rQByypxMKA-goPoEpExI&type=album',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun6-20.userapi.com/impg/hkijg-fGyhQ7KfZHM9hZGWJWGgLmwsD8PNqsLw/V6ncES1Y2hI.jpg?size=130x130&quality=96&sign=7822c0a71e6783098e750959e82f3eae&c_uniq_tag=1oMLBZw_ewKuo6WcT7bBD75rQByypxMKA-goPoEpExI&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun6-20.userapi.com/impg/hkijg-fGyhQ7KfZHM9hZGWJWGgLmwsD8PNqsLw/V6ncES1Y2hI.jpg?size=200x200&quality=96&sign=e00fbde8ae8c4e548f49106697b1a591&c_uniq_tag=APct1WHvRfWxYyl5pijUO_g6wgVX70yvzUmux2yYtL8&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun6-20.userapi.com/impg/hkijg-fGyhQ7KfZHM9hZGWJWGgLmwsD8PNqsLw/V6ncES1Y2hI.jpg?size=320x320&quality=96&sign=02c309d21cf917fc6f0830c93d7e6644&c_uniq_tag=kqpB5ythTY5tRT0Fj_j5cBjkwExHtxSeOU1GduvW92s&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun6-20.userapi.com/impg/hkijg-fGyhQ7KfZHM9hZGWJWGgLmwsD8PNqsLw/V6ncES1Y2hI.jpg?size=510x510&quality=96&sign=1d23780df2083dd9ed6cbef439090a34&c_uniq_tag=uK6H3gSTaoQZTiSADuMrI7gqh7VKb3PHfLXlpvgBd60&type=album',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-20.userapi.com/impg/hkijg-fGyhQ7KfZHM9hZGWJWGgLmwsD8PNqsLw/V6ncES1Y2hI.jpg?size=75x75&quality=96&sign=9926635f0c1c0bc3b93e553ae094a278&c_uniq_tag=NIwiP4bqUd4bGa8TROCtYQyn6N9JtyRR13s9WqDnuIg&type=album',
#                                                                'width': 75},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-20.userapi.com/impg/hkijg-fGyhQ7KfZHM9hZGWJWGgLmwsD8PNqsLw/V6ncES1Y2hI.jpg?size=604x604&quality=96&sign=b5438bcd4bb3596f94e0113e48199611&c_uniq_tag=Iat9bWoUHmzaBm-3dVzeflTLSfrCU_dcLvCKqopWV3Y&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-20.userapi.com/impg/hkijg-fGyhQ7KfZHM9hZGWJWGgLmwsD8PNqsLw/V6ncES1Y2hI.jpg?size=807x807&quality=96&sign=ba47bb99f41f5170138d79673e6b9f17&c_uniq_tag=HVOIoL6yB_tR_fRSKtUfk8JUgeMuWHsXmwu_lABNKe0&type=album',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-20.userapi.com/impg/hkijg-fGyhQ7KfZHM9hZGWJWGgLmwsD8PNqsLw/V6ncES1Y2hI.jpg?size=1080x1080&quality=96&sign=5a3dc7333f8b4203b1b6f9673a6c61d9&c_uniq_tag=08h8843Ff2ZU1yzBj311sX4X62Ss66v26gpj1dvrY60&type=album',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '5eaaf46d0cc4e3de9f'},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': 'a311c056dd067f0a61',
#                                                     'album_id': -7,
#                                                     'date': 1707490737,
#                                                     'id': 457346591,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-23.userapi.com/impg/tZ37cHplZ-Dv4uSCg9XE2bkR3j7DKkLgQtnhRA/POqy5GaIavs.jpg?size=130x130&quality=96&sign=5aa0212ce3013e89c0dfed05621d28f8&c_uniq_tag=LQm0AVJaXHvNB8qzP0HlUhv86Q_127tiAOc_O9mAdVg&type=album',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun6-23.userapi.com/impg/tZ37cHplZ-Dv4uSCg9XE2bkR3j7DKkLgQtnhRA/POqy5GaIavs.jpg?size=130x130&quality=96&sign=5aa0212ce3013e89c0dfed05621d28f8&c_uniq_tag=LQm0AVJaXHvNB8qzP0HlUhv86Q_127tiAOc_O9mAdVg&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun6-23.userapi.com/impg/tZ37cHplZ-Dv4uSCg9XE2bkR3j7DKkLgQtnhRA/POqy5GaIavs.jpg?size=200x200&quality=96&sign=135a0f3f6a1d368db2d98f319fd1a598&c_uniq_tag=RznxhA2vZJ4_GKBJ8Z4gSHMpLh3sliWVmx-OaCVBc14&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun6-23.userapi.com/impg/tZ37cHplZ-Dv4uSCg9XE2bkR3j7DKkLgQtnhRA/POqy5GaIavs.jpg?size=320x320&quality=96&sign=e93fb72c57556d0fc02a5edca7ad140f&c_uniq_tag=t-74AQS2qZ6SJVVH61Xw-htI1ny4kVPllOQc6bu49us&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun6-23.userapi.com/impg/tZ37cHplZ-Dv4uSCg9XE2bkR3j7DKkLgQtnhRA/POqy5GaIavs.jpg?size=510x510&quality=96&sign=72d3fc040d82264b44ddf139cdf7e6fc&c_uniq_tag=4Fwx6vdktbJsOTZ6KRM7S3hGw-dP4GYYUxBW-gRDfhs&type=album',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-23.userapi.com/impg/tZ37cHplZ-Dv4uSCg9XE2bkR3j7DKkLgQtnhRA/POqy5GaIavs.jpg?size=75x75&quality=96&sign=a176c35eb95d547926680b4691efef34&c_uniq_tag=ccFMbSdylevFsVVvpaCoEBLCDlh0tZc_Oq0rxB5uiwQ&type=album',
#                                                                'width': 75},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-23.userapi.com/impg/tZ37cHplZ-Dv4uSCg9XE2bkR3j7DKkLgQtnhRA/POqy5GaIavs.jpg?size=604x604&quality=96&sign=c386b0c5f0d2d646b26663943a50ccc2&c_uniq_tag=73Xs2qdHjvoUmEZlTrfZE2pl0xHMtD_OXJlaL4tleTA&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-23.userapi.com/impg/tZ37cHplZ-Dv4uSCg9XE2bkR3j7DKkLgQtnhRA/POqy5GaIavs.jpg?size=807x807&quality=96&sign=e8a7931396b18e9173e4f4ebf6f1506f&c_uniq_tag=lFBJief0WRZLJFhSYdvUUANzGKB4GZ0NGFRtOLUPlyc&type=album',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-23.userapi.com/impg/tZ37cHplZ-Dv4uSCg9XE2bkR3j7DKkLgQtnhRA/POqy5GaIavs.jpg?size=1080x1080&quality=96&sign=3b5eda5dcd1a3c80cb87c197216f6e4a&c_uniq_tag=Iv0u3N9e6duaz9CA7lPgMnuhmzRmeKfawxpZAGtH2vo&type=album',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'f8be65d6734c4e8632'},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': '1b5a6e694d5dbf29b4',
#                                                     'album_id': -7,
#                                                     'date': 1707490737,
#                                                     'id': 457346592,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Xq_pFzE1m34hPYEEYYG-hNm6XV2ur4U8T6gpaQ/crKNnfml2uw.jpg?size=130x130&quality=96&sign=c09b1e114d9c905217411b5ba340e0b2&c_uniq_tag=Va6oIu0LYhOc-cm66GSFxf1K6GpOjtETWAneNW-b5T8&type=album',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Xq_pFzE1m34hPYEEYYG-hNm6XV2ur4U8T6gpaQ/crKNnfml2uw.jpg?size=130x130&quality=96&sign=c09b1e114d9c905217411b5ba340e0b2&c_uniq_tag=Va6oIu0LYhOc-cm66GSFxf1K6GpOjtETWAneNW-b5T8&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Xq_pFzE1m34hPYEEYYG-hNm6XV2ur4U8T6gpaQ/crKNnfml2uw.jpg?size=200x200&quality=96&sign=e09f3f13772c75bfb0a77fc59e24b02a&c_uniq_tag=uwp2j5K_qK6vsUamBMcDmDFcaIN6g6BDbknR0AZlBSU&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Xq_pFzE1m34hPYEEYYG-hNm6XV2ur4U8T6gpaQ/crKNnfml2uw.jpg?size=320x320&quality=96&sign=96ef266b3b2b6306f576d0cd75d8c42d&c_uniq_tag=uhofm7kG5jql34L3pappxPce7t0VYte-PbQYaOocK7A&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Xq_pFzE1m34hPYEEYYG-hNm6XV2ur4U8T6gpaQ/crKNnfml2uw.jpg?size=510x510&quality=96&sign=33ca60d440cafa42cebc9da2ca0f8bd8&c_uniq_tag=3Cjv4kQqMFnUWHTSxOHcTx8p3OHCIDkOGXXB-DI0jQs&type=album',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Xq_pFzE1m34hPYEEYYG-hNm6XV2ur4U8T6gpaQ/crKNnfml2uw.jpg?size=75x75&quality=96&sign=fdac297a06224ed4cd25727070918d5d&c_uniq_tag=MGops3DWJ6D3zGTKOkWvXqjWIhHi4JyXvzzTqh0geaE&type=album',
#                                                                'width': 75},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Xq_pFzE1m34hPYEEYYG-hNm6XV2ur4U8T6gpaQ/crKNnfml2uw.jpg?size=604x604&quality=96&sign=a2c33781b8ecb69cf6511ef50e40bc98&c_uniq_tag=7s6OY1GmBYh7qf5ngm3Uu43CGKdD3MXwAqrsA3iWYB0&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Xq_pFzE1m34hPYEEYYG-hNm6XV2ur4U8T6gpaQ/crKNnfml2uw.jpg?size=807x807&quality=96&sign=7d4fd9ce4cbcd0ce0c1ce725cf82aa90&c_uniq_tag=OV1-A90K_12JuLXZ8wRpvxEqdMqUuzcoh_hSBhg43xI&type=album',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Xq_pFzE1m34hPYEEYYG-hNm6XV2ur4U8T6gpaQ/crKNnfml2uw.jpg?size=1080x1080&quality=96&sign=6500cfcc382e3267d6681dbedd4b7045&c_uniq_tag=ovtJ7QFab9lw6sx5i6WSPvpoMrYZTljTmfzPiC3XBUk&type=album',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '9faaeb7ddb6e0ce35b'},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': '9a29059904366a3e96',
#                                                     'album_id': -7,
#                                                     'date': 1707490737,
#                                                     'id': 457346593,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-21.userapi.com/impg/hjBhMlW-irtSyiQBqcd1nCe0hfrp5WHjaQx_5Q/Ie8lF91Rttc.jpg?size=130x130&quality=96&sign=d1b87abf5d99089edff2c25f8d6fab0c&c_uniq_tag=0WNHXexVEEZkZ1Yz2OWk--QXmTMApSG9XkWCBkyJkhs&type=album',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun6-21.userapi.com/impg/hjBhMlW-irtSyiQBqcd1nCe0hfrp5WHjaQx_5Q/Ie8lF91Rttc.jpg?size=130x130&quality=96&sign=d1b87abf5d99089edff2c25f8d6fab0c&c_uniq_tag=0WNHXexVEEZkZ1Yz2OWk--QXmTMApSG9XkWCBkyJkhs&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun6-21.userapi.com/impg/hjBhMlW-irtSyiQBqcd1nCe0hfrp5WHjaQx_5Q/Ie8lF91Rttc.jpg?size=200x200&quality=96&sign=a1570d1e4e54ec32a1029a966b911025&c_uniq_tag=Ejc-HbpsvrHxtOLsJfqehkyjDfNKWCfMWq6KQzmjCAM&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun6-21.userapi.com/impg/hjBhMlW-irtSyiQBqcd1nCe0hfrp5WHjaQx_5Q/Ie8lF91Rttc.jpg?size=320x320&quality=96&sign=202fb226c6887bf52ae3ea25a152aeb7&c_uniq_tag=JgYAOBjVVfFrpVHU6ewsd0hY4h3y2QAh10RqQsoDLCw&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun6-21.userapi.com/impg/hjBhMlW-irtSyiQBqcd1nCe0hfrp5WHjaQx_5Q/Ie8lF91Rttc.jpg?size=510x510&quality=96&sign=e26d92fa443c219c7e19bfb06aefdbca&c_uniq_tag=6pS7ARwpkM_27WaMCU6D92blPCMt3sme-sPIBiyfC8o&type=album',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-21.userapi.com/impg/hjBhMlW-irtSyiQBqcd1nCe0hfrp5WHjaQx_5Q/Ie8lF91Rttc.jpg?size=75x75&quality=96&sign=8c30a132e6722b34c2fb8261fc541872&c_uniq_tag=kOBodksF0-lT4gRoXxe8zhXWDaf3eFMmq5WXR7NeJxQ&type=album',
#                                                                'width': 75},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-21.userapi.com/impg/hjBhMlW-irtSyiQBqcd1nCe0hfrp5WHjaQx_5Q/Ie8lF91Rttc.jpg?size=604x604&quality=96&sign=42e159e39d1190a7170fee8872d985c0&c_uniq_tag=IXMhThTAPPwhLe20yOF14C8HAiUnrr53rgUV3SuMYdc&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-21.userapi.com/impg/hjBhMlW-irtSyiQBqcd1nCe0hfrp5WHjaQx_5Q/Ie8lF91Rttc.jpg?size=807x807&quality=96&sign=efed63c665820409cfd7497b425658e9&c_uniq_tag=Ewp6_5xpen-oT5jz_2PjZFD-2USDrSZd_2y1BSD__h4&type=album',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-21.userapi.com/impg/hjBhMlW-irtSyiQBqcd1nCe0hfrp5WHjaQx_5Q/Ie8lF91Rttc.jpg?size=1080x1080&quality=96&sign=2f0e20fca3d9503014bc04209477cd8d&c_uniq_tag=U8_ln0wk_S4LL2RbL7SEQB2Ck_lULNwMpIKBBFk2jC4&type=album',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '5cb64e93640043bd6f'},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 370,
#                                       'groups_can_post': True},
#                          'date': 1707490737,
#                          'from_id': -22822305,
#                          'hash': 'hbY9THasqq0BXYmEmg',
#                          'id': 1459709,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1182,
#                                    'repost_disabled': False,
# ...
#                                                     'id': 457341694,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 70,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-23.userapi.com/impg/LVfhF50EYYE8l-_xHghLRWN7VzcXWqvrsRL_SA/z-0PzuvcY6w.jpg?size=75x70&quality=95&sign=1da557381fad769648d4e61ff9bbbea8&c_uniq_tag=o8-DKO76KbGoD6TQK-M4888dC3IC9n3s0HdtC_XtoO8&type=album',
#                                                                'width': 75},
#                                                               {'height': 122,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-23.userapi.com/impg/LVfhF50EYYE8l-_xHghLRWN7VzcXWqvrsRL_SA/z-0PzuvcY6w.jpg?size=130x122&quality=95&sign=d33a10e75dd871c1560d968a86768fdb&c_uniq_tag=WYjxOQg-OuY4w7Ijejnb_jvNzZEFaktmgD-CnzqqT6M&type=album',
#                                                                'width': 130},
#                                                               {'height': 567,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-23.userapi.com/impg/LVfhF50EYYE8l-_xHghLRWN7VzcXWqvrsRL_SA/z-0PzuvcY6w.jpg?size=604x567&quality=95&sign=df4e7542392246d02238cc9feced7d1c&c_uniq_tag=m0W4GE5RrWucgocoCm1l4bB5a_EnF3GZflYfXYkUfQI&type=album',
#                                                                'width': 604},
#                                                               {'height': 758,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-23.userapi.com/impg/LVfhF50EYYE8l-_xHghLRWN7VzcXWqvrsRL_SA/z-0PzuvcY6w.jpg?size=807x758&quality=95&sign=a8b3f589a584c5e5b2c8dfe5b3421d05&c_uniq_tag=9k1OVZG0_MNACUHbYdz00vVFTkwNh5ydhE1Pz9Smvhg&type=album',
#                                                                'width': 807},
#                                                               {'height': 1202,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-23.userapi.com/impg/LVfhF50EYYE8l-_xHghLRWN7VzcXWqvrsRL_SA/z-0PzuvcY6w.jpg?size=1280x1202&quality=95&sign=a40a97f65f69d40240d52d90efe03a8a&c_uniq_tag=CO-MZK0yzvcQ3Hrl0C4ENspx5aFsZwZBZtmbVepI4Wo&type=album',
#                                                                'width': 1280},
#                                                               {'height': 2160,
#                                                                'type': 'w',
#                                                                'url': 'https://sun6-23.userapi.com/impg/LVfhF50EYYE8l-_xHghLRWN7VzcXWqvrsRL_SA/z-0PzuvcY6w.jpg?size=2300x2160&quality=95&sign=841b0e03cfeed47cf54d0b21eb16877e&c_uniq_tag=RxKyxxzQbgwlJ5ke6Hj_-yvdLVX5eY9v5U5goRBsU-8&type=album',
#                                                                'width': 2300},
#                                                               {'height': 122,
#                                                                'type': 'o',
#                                                                'url': 'https://sun6-23.userapi.com/impg/LVfhF50EYYE8l-_xHghLRWN7VzcXWqvrsRL_SA/z-0PzuvcY6w.jpg?size=130x122&quality=95&sign=d33a10e75dd871c1560d968a86768fdb&c_uniq_tag=WYjxOQg-OuY4w7Ijejnb_jvNzZEFaktmgD-CnzqqT6M&type=album',
#                                                                'width': 130},
#                                                               {'height': 188,
#                                                                'type': 'p',
#                                                                'url': 'https://sun6-23.userapi.com/impg/LVfhF50EYYE8l-_xHghLRWN7VzcXWqvrsRL_SA/z-0PzuvcY6w.jpg?size=200x188&quality=95&sign=59d5049a9fcea810d7d78e1a5ae504ad&c_uniq_tag=sIJeC8ku4JDTZZqIz78MbBkgjiUiI0LAOzBD9qK6UsU&type=album',
#                                                                'width': 200},
#                                                               {'height': 301,
#                                                                'type': 'q',
#                                                                'url': 'https://sun6-23.userapi.com/impg/LVfhF50EYYE8l-_xHghLRWN7VzcXWqvrsRL_SA/z-0PzuvcY6w.jpg?size=320x301&quality=95&sign=8808c849b6e3852439ad46dd4e08e18f&c_uniq_tag=-d1RfQbojhVzsVEw3oLz68IZieQQQVRqM-DiYAaSD5Q&type=album',
#                                                                'width': 320},
#                                                               {'height': 479,
#                                                                'type': 'r',
#                                                                'url': 'https://sun6-23.userapi.com/impg/LVfhF50EYYE8l-_xHghLRWN7VzcXWqvrsRL_SA/z-0PzuvcY6w.jpg?size=510x479&quality=95&sign=30cefffbbe43b9fa4d464050c0507268&c_uniq_tag=YeTzGAS_oh9ayswf451CvFvYAHw5iFTFs88od_rrKbM&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '291d15b7d4f24405ff'},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 813,
#                                       'groups_can_post': True},
#                          'date': 1681912092,
#                          'from_id': -22822305,
#                          'hash': 'mgzlEtaJ_dxuMVBegA',
#                          'id': 1402693,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 4930,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 5996, 'user_reposted': 0},
#                          'text': 'Теперь в записях и комментариях можно '
#                                  'скрывать нецензурные выражения: их '
#                                  'автоматически заменит набор символов. Фильтр '
#                                  'включается в настройках профиля. С '
#                                  'сегодняшнего дня функция начнёт постепенно '
#                                  'становиться доступной всем пользователям. \n'
#                                  '\n'
#                                  'Всё это нужно, чтобы вы чувствовали себя '
#                                  'максимально комфортно и могли гибко '
#                                  'управлять своим цифровым пространством. '
#                                  'Ранее для этого мы уже запустили режим '
#                                  '«Личное пространство», который помогает '
#                                  'оградиться от нежелательного внимания, а '
#                                  'также начали предупреждать о подозрительных '
#                                  'собеседниках в VK Мессенджере.',
#                          'type': 'post',
#                          'views': {'count': 834892}},
#                         {'attachments': [{'photo': {'access_key': '70161c5678261634a3',
#                                                     'album_id': -7,
#                                                     'date': 1681804917,
#                                                     'id': 457341671,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1402353,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-22.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=75x75&quality=95&sign=6683d690ddbfd84a7c8d5ed05a56295b&c_uniq_tag=hovrAWvWlJ9L-UN02wjUj2Avnptj81uKeBlBwl48XR4&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-22.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=130x130&quality=95&sign=e634c009e7d4d3682bc23ad1aa62e909&c_uniq_tag=lcOrVowSqtGMxdu4LLsMGxYaAyraO-VZp9hlF8cn-TU&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-22.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=604x604&quality=95&sign=6d3c92893b7bd284067a1e7c26c8aea9&c_uniq_tag=yohMKuJkrK0y_57vUvlduOypvXVxnmt4jY4O_kc6d6s&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-22.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=807x807&quality=95&sign=759ae1d7a6045c7d3ade189eb893a654&c_uniq_tag=xSivO1laMrU4sxIekZwbV9gZdjChG31wiiYmSYYeI5c&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-22.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=1280x1280&quality=95&sign=80ed10ad679a1aa478e9ca08e363aa46&c_uniq_tag=oik5r9fDkY8jAMUBXUJVeKIj0v45b8ocjdQ1BckMT6I&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1920,
#                                                                'type': 'w',
#                                                                'url': 'https://sun6-22.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=1920x1920&quality=95&sign=0671bbe16d11a9aa01af80d29210f91d&c_uniq_tag=hnWaZckgXMKDnHH6lFx9w5D-FoVwodOwWdy2FGNQSXk&type=album',
#                                                                'width': 1920},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun6-22.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=130x130&quality=95&sign=e634c009e7d4d3682bc23ad1aa62e909&c_uniq_tag=lcOrVowSqtGMxdu4LLsMGxYaAyraO-VZp9hlF8cn-TU&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun6-22.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=200x200&quality=95&sign=6002c567dc4a221a9c83032aacb16a26&c_uniq_tag=rjve8pzhDMhBUj7yWBm97cWRdQbUiAZmUm24AyI7Ia8&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun6-22.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=320x320&quality=95&sign=935e2a3d7c19b177b4b83324f87b4be6&c_uniq_tag=iIPRRJmkOi84VIk76ZQ9-XKb-IXF0TMEFCSH13L_9uE&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun6-22.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=510x510&quality=95&sign=9cbb7c8db906d80ff5f1d7223a8b3c68&c_uniq_tag=agyu5wZMecPNSYr7GAMmQvike6abvwHZ9rIGNXq2M-A&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'f294f109b4dffb7b44'},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 319,
#                                       'groups_can_post': True},
#                          'date': 1681804931,
#                          'from_id': -22822305,
#                          'hash': 'Es8ZEYPtblgye-sg0w',
#                          'id': 1402353,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1010,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 2830, 'user_reposted': 0},
#                          'text': 'ВКонтакте проведёт продажу первой '
#                                  'собственной NFT-коллекции CryptoSpotty! Мы '
#                                  'создали 8\u202f000 уникальных токенов, '
#                                  'которые скоро каждый сможет купить в сервисе '
#                                  '[https://vk.com/vk_nft_hub#/home/drop|VK '
#                                  'NFT]. Все вырученные с продажи NFT деньги '
#                                  'направим на восстановление памятника '
#                                  'архитектуры и одного из самых известных '
#                                  'исторических зданий Санкт-Петербурга — '
#                                  'доходного дома Бака. Так цифровое искусство '
#                                  'поможет реальному. \n'
#                                  '\n'
#                                  'Главным героем коллекции стал пёсик-маскот '
#                                  'Спотти. После покупки NFT его можно будет '
#                                  'установить на аватар или загрузить на '
#                                  'витрину в профиле. Подробности — здесь: '
#                                  'vk.com/press/nft-spotty.',
#                          'type': 'post',
#                          'views': {'count': 723592}}]}}

# %%
# Посмотрим на количество результатов:

len(response.json()['response']['items'])
# Out:
# 100

# %%
# Посмотрим на информацию об отдельном сообщении:

response.json()['response']['items'][0]
# Out:
# {'inner_type': 'wall_wallpost',
#  'comments': {'can_post': 1, 'count': 113, 'groups_can_post': True},
#  'marked_as_ads': 0,
#  'hash': 'x29fSzdpVUr9hx0qzg',
#  'type': 'post',
#  'attachments': [{'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1708517042,
#     'id': 457346856,
#     'owner_id': -22822305,
#     'access_key': 'a34be7e861be7dce43',
#     'post_id': 1461677,
#     'sizes': [{'height': 130,
#       'type': 'm',
#       'width': 130,
#       'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=130x130&quality=96&sign=faf26689a0866d04be904d00393bafb7&c_uniq_tag=VSlj9Y7JURFx21teIR6dlfIvwQBfEMXljWRvNQ4YL3M&type=album'},
#      {'height': 130,
#       'type': 'o',
#       'width': 130,
#       'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=130x130&quality=96&sign=faf26689a0866d04be904d00393bafb7&c_uniq_tag=VSlj9Y7JURFx21teIR6dlfIvwQBfEMXljWRvNQ4YL3M&type=album'},
#      {'height': 200,
#       'type': 'p',
#       'width': 200,
#       'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=200x200&quality=96&sign=16b2ef1d30033ba6ee4abf7c04f3f9d6&c_uniq_tag=WhFUpvFCZirCyFkq7-DguijDNasFPPW47Dy2P-vV3Ws&type=album'},
#      {'height': 320,
#       'type': 'q',
#       'width': 320,
#       'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=320x320&quality=96&sign=8b082f8aad764a79a43fceacf9cca1bd&c_uniq_tag=jDRs5UPvrPcZ6oJYf7Ert8tGeDNkG68RfoTqHByscxM&type=album'},
#      {'height': 510,
#       'type': 'r',
#       'width': 510,
#       'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=510x510&quality=96&sign=b748e0275761094a91e5fb692b57898d&c_uniq_tag=ZbzXpdYeSaDbo4tHJFY_PH3UyPLcg3bbO8LJx_SWFhk&type=album'},
#      {'height': 75,
#       'type': 's',
#       'width': 75,
#       'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=75x75&quality=96&sign=619f77933e9d5ffc10d91f50548292c4&c_uniq_tag=Oe10bxC63HI7rvw87wbJjagkQt2-VGvClmGCGd3nMcw&type=album'},
#      {'height': 604,
#       'type': 'x',
#       'width': 604,
#       'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=604x604&quality=96&sign=780acef83aa31eaa906d4fe2b27351cf&c_uniq_tag=3cgsebGqMOU6WdwB_-fiGIsAKblqWPZ_kbya3aIqw0c&type=album'},
#      {'height': 807,
#       'type': 'y',
#       'width': 807,
#       'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=807x807&quality=96&sign=49b0dac24956b3026af5581acc6f4d5b&c_uniq_tag=vyhFH9mkt6jYdsIfxswJPUem98t6OWSj0OB1NvhwVs8&type=album'},
#      {'height': 1080,
#       'type': 'z',
#       'width': 1080,
#       'url': 'https://sun6-22.userapi.com/impg/cph0cVYFR6lQPkk2m0dyC_yMHgSibqgLjbzaiQ/BVOCKsziy_I.jpg?size=1080x1080&quality=96&sign=f2bf3703ab0eabec7f68062c38230834&c_uniq_tag=fVVOim8C6T-ZvfyaRKyEbLKx63RfDlH7sXghlMH395c&type=album'}],
#     'text': '',
#     'user_id': 100,
#     'web_view_token': 'e2af357ee2593612b6'}}],
#  'date': 1708517100,
#  'from_id': -22822305,
#  'id': 1461677,
#  'likes': {'can_like': 1,
#   'count': 1493,
#   'user_likes': 0,
#   'can_publish': 1,
#   'repost_disabled': False},
#  'owner_id': -22822305,
#  'post_source': {'type': 'vk'},
#  'post_type': 'post',
#  'reposts': {'count': 137, 'user_reposted': 0},
#  'text': 'А это всегда приятно!',
#  'views': {'count': 353915}}

# %%
# Давайте соберём итоговую статистику для последних десяти непустых сообщений в словарь stats. В качестве ключа 
# будем использовать начало сообщения (если начало сообщения пустое, то информацию о таком сообщении проигнорируем), 
# в качестве значения — список с тремя интересующими нас метриками и временем публикации (комментарии, лайки, 
# репосты, дата публикации):

stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'[https://vk.com/fest_ufa|Уфа],': [124, 755, 224, 1706860913],
#  'А похвастайтесь своими результ': [267, 302, 32, 1708344300],
#  'А это всегда приятно!': [113, 1493, 137, 1708517100],
#  'В такие моменты важно говорить': [268, 3449, 395, 1707300472],
#  'ВКонтакте обновились истории. ': [325, 965, 266, 1706598480],
#  'ВКонтакте появился [vk.com/saf': [455, 401, 72, 1707996601],
#  'Всех с Днём влюблённых! 💙\n\nНад': [250, 443, 39, 1707908176],
#  'Как сделать отличную аватарку ': [370, 1182, 105, 1707490737],
#  'Какие персонажи — такие и чёрн': [334, 848, 115, 1706950860],
#  'Скидывайте в комментарии ваше ': [1002, 883, 171, 1707136200]}
